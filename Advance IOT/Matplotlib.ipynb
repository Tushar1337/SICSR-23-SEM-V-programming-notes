# %%
import matplotlib.pyplot as plt

a=[1,2,3,4,5]
b=[0,0.6,0.2,15,10,8,16,21]
plt.plot(a)

# o is for cirlces and r is for red
plt.plot(b,"or")

plt.plot(list(range(0,22,3)))

#naming the x-axis

# %%
#importing the required module
import matplotlib.pyplot as plt

x=[1,2,3]
y=[2,4,1]

plt.plot(x,y)

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('First Graph')

plt.show()
